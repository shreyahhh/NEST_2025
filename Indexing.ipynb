# %%
import pandas as pd

# Load the first CSV file (source file)
df_source = pd.read_csv('intervention.csv')

# Load the second CSV file (destination file)
df_dest = pd.read_csv('final_dataset.csv')

# Copy the column from source CSV to destination CSV
# Assuming the column name you want to copy is 'column_name'
df_dest['Interventions_embeddings'] = df_source['Interventions_embeddings']

# Save the updated destination DataFrame to a new CSV file
#df_dest.to_csv('updated_destination_file.csv', index=False)

# %%
df_dest.columns
# Out:
# Index(['NCT Number', 'Study Status', 'Study Results', 'Conditions',
#        'Interventions', 'Sponsor', 'Sex', 'Age', 'Phases', 'Enrollment',
#        'Funder Type', 'Study Type', 'Study Design', 'Start Date',
#        'Completion Date', 'Last Update Posted', 'Locations',
#        'Study Recruitment Rate', 'Allocation', 'Intervention Model', 'Masking',
#        'Primary Purpose', 'Allocation_Indexed', 'Intervention Model_Indexed',
#        'Masking_Indexed', 'Primary Purpose_Indexed', 'Age_Encoded',
#        'Sex_Encoded', 'Phases_Encoded', 'Interventions_embeddings'],
#       dtype='object')

# %%
df_source = pd.read_csv('duration.csv')



# Copy the column from source CSV to destination CSV
# Assuming the column name you want to copy is 'column_name'
df_dest["Duration (Months)"] = df_source["Duration (Months)"]

# %%
df_dest.columns
# Out:
# Index(['NCT Number', 'Study Status', 'Study Results', 'Conditions',
#        'Interventions', 'Sponsor', 'Sex', 'Age', 'Phases', 'Enrollment',
#        'Funder Type', 'Study Type', 'Study Design', 'Start Date',
#        'Completion Date', 'Last Update Posted', 'Locations',
#        'Study Recruitment Rate', 'Allocation', 'Intervention Model', 'Masking',
#        'Primary Purpose', 'Allocation_Indexed', 'Intervention Model_Indexed',
#        'Masking_Indexed', 'Primary Purpose_Indexed', 'Age_Encoded',
#        'Sex_Encoded', 'Phases_Encoded', 'Interventions_embeddings',
#        'Duration (Months)'],
#       dtype='object')

# %%
df_source = pd.read_csv('conditions.csv')



# Copy the column from source CSV to destination CSV
# Assuming the column name you want to copy is 'column_name'
df_dest["embeddings"] = df_source["embeddings"]

# %%
df_dest.rename(columns={'embeddings': 'conditions_embeddings'})
# Out:
#         NCT Number Study Status Study Results  \
# 0      NCT00900809    COMPLETED            NO
# 1      NCT01113515    COMPLETED           YES
# 2      NCT01288573    COMPLETED            NO
# 3      NCT01336660    COMPLETED            NO
# 4      NCT01376167    COMPLETED           YES
# ...            ...          ...           ...
# 20580  NCT04229433    COMPLETED            NO
# 20581  NCT04883333    COMPLETED            NO
# 20582  NCT02453087    COMPLETED            NO
# 20583  NCT03850587    COMPLETED            NO
# 20584  NCT03591887    COMPLETED            NO
#
#                                               Conditions  \
# 0                                 Acute Myeloid Leukemia
# 1                                    Diabetic Foot Ulcer
# 2      Ewing's Sarcoma/Soft Tissue Sarcoma|Neuroblast...
# 3                            Poisoning by Scorpion Sting
# 4                                         Malaria, Vivax
# ...                                                  ...
# ...

# %%
df_source = pd.read_csv('sites.csv')



# Copy the column from source CSV to destination CSV
# Assuming the column name you want to copy is 'column_name'
df_dest["no_of_sites"] = df_source["Location_Count"]

# %%
df_dest.columns
# Out:
# Index(['NCT Number', 'Study Status', 'Study Results', 'Conditions',
#        'Interventions', 'Sponsor', 'Sex', 'Age', 'Phases', 'Enrollment',
#        'Funder Type', 'Study Type', 'Study Design', 'Start Date',
#        'Completion Date', 'Last Update Posted', 'Locations',
#        'Study Recruitment Rate', 'Allocation', 'Intervention Model', 'Masking',
#        'Primary Purpose', 'Allocation_Indexed', 'Intervention Model_Indexed',
#        'Masking_Indexed', 'Primary Purpose_Indexed', 'Age_Encoded',
#        'Sex_Encoded', 'Phases_Encoded', 'Interventions_embeddings',
#        'Duration (Months)', 'embeddings', 'no_of_sites'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

categorical_columns = ["Funder Type"]

# Create indexed column names for these columns
categorical_columns_indexed = [col + "_Indexed" for col in categorical_columns]

# Apply LabelEncoder to each specified column
label_encoders = {}
for col, indexed_col in zip(categorical_columns, categorical_columns_indexed):
    le = LabelEncoder()
    df_dest[indexed_col] = le.fit_transform(df_dest[col])
    label_encoders[col] = le

# %%
df_dest.head()
# Out:
#     NCT Number Study Status Study Results  \
# 0  NCT00900809    COMPLETED            NO
# 1  NCT01113515    COMPLETED           YES
# 2  NCT01288573    COMPLETED            NO
# 3  NCT01336660    COMPLETED            NO
# 4  NCT01376167    COMPLETED           YES
#
#                                           Conditions  \
# 0                             Acute Myeloid Leukemia
# 1                                Diabetic Foot Ulcer
# 2  Ewing's Sarcoma/Soft Tissue Sarcoma|Neuroblast...
# 3                        Poisoning by Scorpion Sting
# 4                                     Malaria, Vivax
#
#                                        Interventions  \
# 0                  BIOLOGICAL: Neukoplastâ„¢ (NK-92)
# 1  DRUG: Esmolol hydrochloride|DRUG: Esmolol hydr...
# 2  DRUG: plerixafor|DRUG: plerixafor|DRUG: plerix...
# 3  BIOLOGICAL: Equine F(ab')2 antivenom|OTHER: In...
# 4  DRUG: Chloroquine 600mg|DRUG: Chloroquine 300m...
#
# ...

# %%
df_dest.drop(columns=["Age","Phases", "Sex" ])
# Out:
#         NCT Number Study Status Study Results  \
# 0      NCT00900809    COMPLETED            NO
# 1      NCT01113515    COMPLETED           YES
# 2      NCT01288573    COMPLETED            NO
# 3      NCT01336660    COMPLETED            NO
# 4      NCT01376167    COMPLETED           YES
# ...            ...          ...           ...
# 20580  NCT04229433    COMPLETED            NO
# 20581  NCT04883333    COMPLETED            NO
# 20582  NCT02453087    COMPLETED            NO
# 20583  NCT03850587    COMPLETED            NO
# 20584  NCT03591887    COMPLETED            NO
#
#                                               Conditions  \
# 0                                 Acute Myeloid Leukemia
# 1                                    Diabetic Foot Ulcer
# 2      Ewing's Sarcoma/Soft Tissue Sarcoma|Neuroblast...
# 3                            Poisoning by Scorpion Sting
# 4                                         Malaria, Vivax
# ...                                                  ...
# ...

# %%
df_dest.drop(columns=["Allocation","Conditions", "Interventions", 'Sex', 'Age', 'Phases','Start Date',
       'Completion Date', 'Last Update Posted', 'Locations', 'Intervention Model','Masking', 'Primary Purpose'])
# Out:
#         NCT Number Study Status Study Results  \
# 0      NCT00900809    COMPLETED            NO
# 1      NCT01113515    COMPLETED           YES
# 2      NCT01288573    COMPLETED            NO
# 3      NCT01336660    COMPLETED            NO
# 4      NCT01376167    COMPLETED           YES
# ...            ...          ...           ...
# 20580  NCT04229433    COMPLETED            NO
# 20581  NCT04883333    COMPLETED            NO
# 20582  NCT02453087    COMPLETED            NO
# 20583  NCT03850587    COMPLETED            NO
# 20584  NCT03591887    COMPLETED            NO
#
#                                   Sponsor  Enrollment Funder Type  \
# 0                       ImmunityBio, Inc.           7    INDUSTRY
# 1         Novalead Pharma Private Limited          44    INDUSTRY
# 2               Genzyme, a Sanofi Company          46    INDUSTRY
# 3          Instituto Bioclon S.A. de C.V.          56    INDUSTRY
# 4                         GlaxoSmithKline         851    INDUSTRY
# ...

# %%
df_dest.columns
# Out:
# Index(['NCT Number', 'Study Status', 'Study Results', 'Conditions',
#        'Interventions', 'Sponsor', 'Sex', 'Age', 'Phases', 'Enrollment',
#        'Funder Type', 'Study Type', 'Study Design', 'Start Date',
#        'Completion Date', 'Last Update Posted', 'Locations',
#        'Study Recruitment Rate', 'Allocation', 'Intervention Model', 'Masking',
#        'Primary Purpose', 'Allocation_Indexed', 'Intervention Model_Indexed',
#        'Masking_Indexed', 'Primary Purpose_Indexed', 'Age_Encoded',
#        'Sex_Encoded', 'Phases_Encoded', 'Interventions_embeddings',
#        'Duration (Months)', 'embeddings', 'no_of_sites',
#        'Funder Type_Indexed'],
#       dtype='object')

# %%
df_dest.to_csv("final_dataset_1.csv", index = False)

# %%
import pandas as pd
df_source = pd.read_csv('dataset_2.csv')

# Load the second CSV file (destination file)
df_dest = pd.read_csv('Final_dataset.csv')

# Copy the column from source CSV to destination CSV
# Assuming the column name you want to copy is 'column_name'
#df_dest['Interventions_embeddings'] = df_source['Interventions_embeddings']

# %%
df_dest = df_dest.drop(["Age_Encoded", "Sex_Encoded", "Phases_Encoded"], axis=1)

# %%
df_dest.columns
# Out:
# Index(['NCT Number', 'Enrollment', 'Study Recruitment Rate',
#        'Allocation_Indexed', 'Intervention Model_Indexed', 'Masking_Indexed',
#        'Primary Purpose_Indexed', 'Interventions_embeddings',
#        'Duration (Months)', 'embeddings', 'no_of_sites', 'Funder Type_Indexed',
#        'Sponsor_encoded'],
#       dtype='object')

# %%
df_source = pd.read_csv('dataset_2.csv')


df_dest['Sex_Encoded'] = df_source['Sex_Indexed']

# %%
df_source = pd.read_csv('dataset_2.csv')


df_dest['Age_Encoded'] = df_source['Age_Indexed']

# %%
df_source = pd.read_csv('dataset_2.csv')


df_dest['Phases_Encoded'] = df_source['Phases_Indexed']

# %%
df_dest.columns
# Out:
# Index(['NCT Number', 'Enrollment', 'Study Recruitment Rate',
#        'Allocation_Indexed', 'Intervention Model_Indexed', 'Masking_Indexed',
#        'Primary Purpose_Indexed', 'Interventions_embeddings',
#        'Duration (Months)', 'embeddings', 'no_of_sites', 'Funder Type_Indexed',
#        'Sponsor_encoded', 'Sex_Encoded', 'Age_Encoded', 'Phases_Encoded'],
#       dtype='object')

# %%
df_dest.to_csv("Final_dataset.csv", index=False)
